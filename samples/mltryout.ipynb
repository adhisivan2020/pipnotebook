# %% [markdown]
# ### Machine Learning Basics try out

# %%
pip install Pandas
# Out:
# Collecting Pandas
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Pandas) (2.8.1)
# Collecting numpy>=1.16.5
#   Downloading numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 141 kB/s  eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->Pandas) (1.15.0)
# Installing collected packages: numpy, Pandas
# Successfully installed Pandas-1.2.4 numpy-1.20.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pwd
# Out:
# '/home/jovyan/samples'

# %%
import csv
import numpy as np

print ('***Read using Python Library***')
path = r"/home/jovyan/data/student.csv"

with open(path,'r') as f:
   reader = csv.reader(f,delimiter = ',')
   headers = next(reader)
   data = list(reader)
   data = np.array(data) #.astype(str)
    
print(headers)
print(data.shape)
print(data[:])
# Out:
# ***Read using Python Library***
# ['student_name', 'age', 'class', 'section']
# (6, 4)
# [['ajay' '12' 'VII' 'B']
#  ['mani' '12' 'VII' 'B']
#  ['raj' '12' 'VII' 'C']
#  ['baskar' '12' 'VII' 'B']
#  ['velan' '12' 'VII' 'C']
#  ['muthu' '12' 'VII' 'B']]

# %% [markdown]
# ### Statistical summary of CSV data

# %%
import csv
import numpy as np
from pandas import read_csv

data2 = read_csv(path)
print(data2.shape)
print(data2[:3])
print (data2.describe())
# Out:
# (6, 4)
#   student_name  age class section
# 0         ajay   12   VII       B
# 1         mani   12   VII       B
# 2          raj   12   VII       C
#         age
# count   6.0
# mean   12.0
# std     0.0
# min    12.0
# 25%    12.0
# 50%    12.0
# 75%    12.0
# max    12.0

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 2.7 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 13.3 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 61.0 MB/s eta 0:00:01
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.1 pillow-8.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot
from pandas import read_csv
data = read_csv(path)
data.hist()
pyplot.show()
