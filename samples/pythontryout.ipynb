# %% [markdown]
# ### Try out different python program snippets

# %%
print ('Python try out starts now...')
# Out:
# Python try out starts now...

# %%
pip --version
# Out:
# pip 21.0.1 from /srv/conda/envs/notebook/lib/python3.7/site-packages/pip (python 3.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
a = 5
b = 10

if (a < b):
    print ('a less than b')
# Out:
# a less than b

# %%
"""
This section is a comment section
Multiple lines allowed with in it
"""

print ('commenting examples')
# Out:
# commenting examples

# %%
#variable demo

x = 2
y = 'text'
z = 3.2


print (type(x))
print (type(y))
print (type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
#variable assignment demo

x, y, z = 100, 200, 300

print("before : " + str(y))

x = y = z = 50

print("after : " + str(y))
# Out:
# before : 200
# after : 50

# %%
#function example

def Myfunc():
    x = 'this will be printed'
    print(x)
    
    
Myfunc()
# Out:
# this will be printed

# %%
#string demo

a = '''Multi line text display 
using triple quotes in python'''

if ('text' in a):
    print ('the word text found in a')
# Out:
# the word text found in a
